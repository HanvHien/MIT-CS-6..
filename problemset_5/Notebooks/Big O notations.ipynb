# %% [markdown]
# For each of the following expressions, select the order of growth class that best describes it from the following list: $O(1), O(\log (n)), O(n), O(n\log (n)), O(n^ c)$. Assume $c$ is some constant.
#
# http://bigocheatsheet.com/

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
n = np.arange(0,1e8,1000)

y = 0.0000001*n + 1000000

# %%
plt.figure(1, figsize=(8,8))

plt.plot(n,y)
plt.show()

# %%
y = 0.0001*n**2 + 20000*n - 90000

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()

# %%
n = np.arange(1,1e8,100)
y = 20*n + 900*np.log(n) + 100000

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()

# %%
n = np.arange(1,1e8,100)
y = 30* n**2+n*np.log(n)

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()

# %%
n = np.arange(1,1e8,100)
y = n*np.log(n)-3000*n

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()

# %%
n = np.arange(1,1e8,100)
y = n*np.log(n)+n**2+n+np.log(n)+1+2**n
# Out:
# C:\Users\IBM_ADMIN\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: RuntimeWarning: overflow encountered in power
#   app.launch_new_instance()

# %%
plt.figure(1, figsize=(8,8))
plt.plot(n,y)
plt.show()
